# %% [markdown]
# <a href="https://colab.research.google.com/github/matheusrb/panorama_covid19/blob/master/Panorama_do_COVID_19_no_Mundo_dados_OWID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Panorama do COVID-19 no Brasil
#
# COVID-19 é uma doença infecciosa causada por um novo tipo de coronavírus.
#
# Transmitido principalmente por meio de gotículas provenientes de tosses ou espirros de pessoas infectadas, a gravidade dos sintomas varia muito de pessoa para pessoa.
#
# Fato é, não se sabe muita coisa a respeito do COVID-19. Estudos estão sendo realizados no mundo todo, porém os resultados ainda não são conclusivos e definitivos.
#
# <center><img alt="Colaboratory logo" width="50%" src="https://static.poder360.com.br/2022/12/coronavirus-imagem-1-848x477.jpg"></center>
#
# Até o presente momento, observa-se que cerca de 80% dos casos confirmados são assintomáticos e rápidos. A maioria das pessoas que se encaixam nesse grupo, se recupera sem nenhuma sequela.
#
# No entanto, 15% das pessoas terão infecções graves e precisarão de oxigênio. O restante das pessoas, que representam 5%, serão classificadas como infecções muito graves e precisarão de ventilação assistida, por meio de respiradores mecânicos em ambiente hospitalar.
#
# Com o objetivo de elevar a consciência situacional a respeito do COVID-19 no Brasil, irei realizar uma análise sobre os dados públicos da doença.
#
#
# Como complemento a análise, foi utilizada a base de dados referente ao preço do combustível e dados relacionados ao IGPM - Índice Geral de Preços do Mercado, para avlaiarmos os impactos econômicos peírodo a período.
#
# [Dados Históricos Combustível](https://www.gov.br/anp/pt-br/centrais-de-conteudo/dados-abertos/serie-historica-de-precos-de-combustiveis)
#
# [Dados Históricos IGPM](https://www.dadosdemercado.com.br/economia/igp-m)

# %% [markdown]
# ## Obtenção dos Dados
#
# Os dados abordados neste notebook podem ser encontrados [no repositorio do Our World in Data](https://github.com/owid/covid-19-data/tree/master/public/data)
#
# A esta altura, uma vez que o COVID-19 encontra-se controlado, os dados adicionados ao repositório passaram a ser mais escassos, de forma que dados recentes não podem ser encontrados, apesar das atualizações diárias ainda ocorrerem
#
# ### Dicionário de Variáveis
# | Variable                         | Description                                                                                                                                                                                            |
# |:---------------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | `total_cases`                    | Total confirmed cases of COVID-19. Counts can include probable cases, where reported.                                                                                                                  |
# | `new_cases`                      | New confirmed cases of COVID-19. Counts can include probable cases, where reported. In rare cases where our source reports a negative daily change due to a data correction, we set this metric to NA. |
# | `new_cases_smoothed`             | New confirmed cases of COVID-19 (7-day smoothed). Counts can include probable cases, where reported.                                                                                                   |
# | `total_cases_per_million`        | Total confirmed cases of COVID-19 per 1,000,000 people. Counts can include probable cases, where reported.                                                                                             |
# | `new_cases_per_million`          | New confirmed cases of COVID-19 per 1,000,000 people. Counts can include probable cases, where reported.                                                                                               |
# | `new_cases_smoothed_per_million` | New confirmed cases of COVID-19 (7-day smoothed) per 1,000,000 people. Counts can include probable cases, where reported.                                                                              |
#
# ### Confirmed deaths
#
# | Variable                          | Description                                                                                                                                                                                               |
# |:----------------------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | `total_deaths`                    | Total deaths attributed to COVID-19. Counts can include probable deaths, where reported.                                                                                                                  |
# | `new_deaths`                      | New deaths attributed to COVID-19. Counts can include probable deaths, where reported. In rare cases where our source reports a negative daily change due to a data correction, we set this metric to NA. |
# | `new_deaths_smoothed`             | New deaths attributed to COVID-19 (7-day smoothed). Counts can include probable deaths, where reported.                                                                                                   |
# | `total_deaths_per_million`        | Total deaths attributed to COVID-19 per 1,000,000 people. Counts can include probable deaths, where reported.                                                                                             |
# | `new_deaths_per_million`          | New deaths attributed to COVID-19 per 1,000,000 people. Counts can include probable deaths, where reported.                                                                                               |
# | `new_deaths_smoothed_per_million` | New deaths attributed to COVID-19 (7-day smoothed) per 1,000,000 people. Counts can include probable deaths, where reported.                                                                              |
#
# #### Notes:
# * Due to varying protocols and challenges in the attribution of the cause of death, the number of confirmed deaths may not accurately represent the true number of deaths caused by COVID-19.
#
# ### Excess mortality
#
# | Variable                                  | Description                                                                                                                                                                                                                                                                                   |
# |:------------------------------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | `excess_mortality`                        | Percentage difference between the reported number of weekly or monthly deaths in 2020–2021 and the projected number of deaths for the same period based on previous years. For more information, see https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality           |
# | `excess_mortality_cumulative`             | Percentage difference between the cumulative number of deaths since 1 January 2020 and the cumulative projected deaths for the same period based on previous years. For more information, see https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality                  |
# | `excess_mortality_cumulative_absolute`    | Cumulative difference between the reported number of deaths since 1 January 2020 and the projected number of deaths for the same period based on previous years. For more information, see https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality                     |
# | `excess_mortality_cumulative_per_million` | Cumulative difference between the reported number of deaths since 1 January 2020 and the projected number of deaths for the same period based on previous years, per million people. For more information, see https://github.com/owid/covid-19-data/tree/master/public/data/excess_mortality |
#
# ### Hospital & ICU
#
# | Variable                             | Description                                                                                                                                               |
# |:-------------------------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------------|
# | `icu_patients`                       | Number of COVID-19 patients in intensive care units (ICUs) on a given day                                                                                 |
# | `icu_patients_per_million`           | Number of COVID-19 patients in intensive care units (ICUs) on a given day per 1,000,000 people                                                            |
# | `hosp_patients`                      | Number of COVID-19 patients in hospital on a given day                                                                                                    |
# | `hosp_patients_per_million`          | Number of COVID-19 patients in hospital on a given day per 1,000,000 people                                                                               |
# | `weekly_icu_admissions`              | Number of COVID-19 patients newly admitted to intensive care units (ICUs) in a given week (reporting date and the preceeding 6 days)                      |
# | `weekly_icu_admissions_per_million`  | Number of COVID-19 patients newly admitted to intensive care units (ICUs) in a given week per 1,000,000 people (reporting date and the preceeding 6 days) |
# | `weekly_hosp_admissions`             | Number of COVID-19 patients newly admitted to hospitals in a given week (reporting date and the preceeding 6 days)                                        |
# | `weekly_hosp_admissions_per_million` | Number of COVID-19 patients newly admitted to hospitals in a given week per 1,000,000 people (reporting date and the preceeding 6 days)                   |
#
# ### Policy responses
#
# | Variable           | Description                                                                                                                                                                                                         |
# |:-------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | `stringency_index` | Government Response Stringency Index: composite measure based on 9 response indicators including school closures, workplace closures, and travel bans, rescaled to a value from 0 to 100 (100 = strictest response) |
#
# ### Reproduction rate
#
# | Variable            | Description                                                                                                                                   |
# |:--------------------|:----------------------------------------------------------------------------------------------------------------------------------------------|
# | `reproduction_rate` | Real-time estimate of the effective reproduction rate (R) of COVID-19. See https://github.com/crondonm/TrackingR/tree/main/Estimates-Database |
#
# ### Tests & positivity
# On 23 June 2022, we stopped adding new datapoints to our COVID-19 testing dataset. You can read more at https://github.com/owid/covid-19-data/discussions/2667.
#
# | Variable                          | Description                                                                                                                                                                                                                                                                                                                                                                                                                                                           |
# |:----------------------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | `total_tests`                     | Total tests for COVID-19                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | `new_tests`                       | New tests for COVID-19 (only calculated for consecutive days)                                                                                                                                                                                                                                                                                                                                                                                                         |
# | `total_tests_per_thousand`        | Total tests for COVID-19 per 1,000 people                                                                                                                                                                                                                                                                                                                                                                                                                             |
# | `new_tests_per_thousand`          | New tests for COVID-19 per 1,000 people                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | `new_tests_smoothed`              | New tests for COVID-19 (7-day smoothed). For countries that don't report testing data on a daily basis, we assume that testing changed equally on a daily basis over any periods in which no data was reported. This produces a complete series of daily figures, which is then averaged over a rolling 7-day window                                                                                                                                                  |
# | `new_tests_smoothed_per_thousand` | New tests for COVID-19 (7-day smoothed) per 1,000 people                                                                                                                                                                                                                                                                                                                                                                                                              |
# | `positive_rate`                   | The share of COVID-19 tests that are positive, given as a rolling 7-day average (this is the inverse of tests_per_case)                                                                                                                                                                                                                                                                                                                                               |
# | `tests_per_case`                  | Tests conducted per new confirmed case of COVID-19, given as a rolling 7-day average (this is the inverse of positive_rate)                                                                                                                                                                                                                                                                                                                                           |
# | `tests_units`                     | Units used by the location to report its testing data. A country file can't contain mixed units. All metrics concerning testing data use the specified test unit. Valid units are 'people tested' (number of people tested), 'tests performed' (number of tests performed. a single person can be tested more than once in a given day) and 'samples tested' (number of samples tested. In some cases, more than one sample may be required to perform a given test.) |
#
# ### Vaccinations
#
# | Variable                                     | Description                                                                                                                                                                                                                                                                                                                                       |
# |:---------------------------------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | `total_vaccinations`                         | Total number of COVID-19 vaccination doses administered                                                                                                                                                                                                                                                                                           |
# | `people_vaccinated`                          | Total number of people who received at least one vaccine dose                                                                                                                                                                                                                                                                                     |
# | `people_fully_vaccinated`                    | Total number of people who received all doses prescribed by the initial vaccination protocol                                                                                                                                                                                                                                                      |
# | `total_boosters`                             | Total number of COVID-19 vaccination booster doses administered (doses administered beyond the number prescribed by the vaccination protocol)                                                                                                                                                                                                     |
# | `new_vaccinations`                           | New COVID-19 vaccination doses administered (only calculated for consecutive days)                                                                                                                                                                                                                                                                |
# | `new_vaccinations_smoothed`                  | New COVID-19 vaccination doses administered (7-day smoothed). For countries that don't report vaccination data on a daily basis, we assume that vaccination changed equally on a daily basis over any periods in which no data was reported. This produces a complete series of daily figures, which is then averaged over a rolling 7-day window |
# | `total_vaccinations_per_hundred`             | Total number of COVID-19 vaccination doses administered per 100 people in the total population                                                                                                                                                                                                                                                    |
# | `people_vaccinated_per_hundred`              | Total number of people who received at least one vaccine dose per 100 people in the total population                                                                                                                                                                                                                                              |
# | `people_fully_vaccinated_per_hundred`        | Total number of people who received all doses prescribed by the initial vaccination protocol per 100 people in the total population                                                                                                                                                                                                               |
# | `total_boosters_per_hundred`                 | Total number of COVID-19 vaccination booster doses administered per 100 people in the total population                                                                                                                                                                                                                                            |
# | `new_vaccinations_smoothed_per_million`      | New COVID-19 vaccination doses administered (7-day smoothed) per 1,000,000 people in the total population                                                                                                                                                                                                                                         |
# | `new_people_vaccinated_smoothed`             | Daily number of people receiving their first vaccine dose (7-day smoothed)                                                                                                                                                                                                                                                                        |
# | `new_people_vaccinated_smoothed_per_hundred` | Daily number of people receiving their first vaccine dose (7-day smoothed) per 100 people in the total population                                                                                                                                                                                                                                 |
#
# ### Others
#
# | Variable                     | Description                                                                                                                                                                                                                                |
# |:-----------------------------|:-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | `iso_code`                   | ISO 3166-1 alpha-3 – three-letter country codes. Note that OWID-defined regions (e.g. continents like 'Europe') contain prefix 'OWID_'.                                                                                                    |
# | `continent`                  | Continent of the geographical location                                                                                                                                                                                                     |
# | `location`                   | Geographical location                                                                                                                                                                                                                      |
# | `date`                       | Date of observation                                                                                                                                                                                                                        |
# | `population`                 | Population (latest available values). See https://github.com/owid/covid-19-data/blob/master/scripts/input/un/population_latest.csv for full list of sources                                                                                |
# | `population_density`         | Number of people divided by land area, measured in square kilometers, most recent year available                                                                                                                                           |
# | `median_age`                 | Median age of the population, UN projection for 2020                                                                                                                                                                                       |
# | `aged_65_older`              | Share of the population that is 65 years and older, most recent year available                                                                                                                                                             |
# | `aged_70_older`              | Share of the population that is 70 years and older in 2015                                                                                                                                                                                 |
# | `gdp_per_capita`             | Gross domestic product at purchasing power parity (constant 2011 international dollars), most recent year available                                                                                                                        |
# | `extreme_poverty`            | Share of the population living in extreme poverty, most recent year available since 2010                                                                                                                                                   |
# | `cardiovasc_death_rate`      | Death rate from cardiovascular disease in 2017 (annual number of deaths per 100,000 people)                                                                                                                                                |
# | `diabetes_prevalence`        | Diabetes prevalence (% of population aged 20 to 79) in 2017                                                                                                                                                                                |
# | `female_smokers`             | Share of women who smoke, most recent year available                                                                                                                                                                                       |
# | `male_smokers`               | Share of men who smoke, most recent year available                                                                                                                                                                                         |
# | `handwashing_facilities`     | Share of the population with basic handwashing facilities on premises, most recent year available                                                                                                                                          |
# | `hospital_beds_per_thousand` | Hospital beds per 1,000 people, most recent year available since 2010                                                                                                                                                                      |
# | `life_expectancy`            | Life expectancy at birth in 2019                                                                                                                                                                                                           |
# | `human_development_index`    | A composite index measuring average achievement in three basic dimensions of human development—a long and healthy life, knowledge and a decent standard of living. Values for 2019, imported from http://hdr.undp.org/en/indicators/137506 |

# %%
# !pip install chardet

# %%
#import das bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from datetime import datetime, timedelta
import requests
import chardet
from io import StringIO

# %% [markdown]
# # Dados Combustíveis

# %% [markdown]
# ## Importação e filtragem da base de dados

# %%
df_combustivel = pd.DataFrame()

# importar o dataset COVID-19 para um DataaFrame
enderecos = ['https://raw.githubusercontent.com/matheusrb/panorama_covid19/master/Dados%20Combustível/ca-2019-02.csv',
             'https://raw.githubusercontent.com/matheusrb/panorama_covid19/master/Dados%20Combustível/ca-2020-01.csv',
             'https://raw.githubusercontent.com/matheusrb/panorama_covid19/master/Dados%20Combustível/ca-2020-02.csv',
             'https://raw.githubusercontent.com/matheusrb/panorama_covid19/master/Dados%20Combustível/ca-2021-01.csv',
             'https://raw.githubusercontent.com/matheusrb/panorama_covid19/master/Dados%20Combustível/ca-2021-02.csv',
             'https://raw.githubusercontent.com/matheusrb/panorama_covid19/master/Dados%20Combustível/ca-2022-01.csv',
             'https://raw.githubusercontent.com/matheusrb/panorama_covid19/master/Dados%20Combustível/ca-2022-02.csv',
             'https://raw.githubusercontent.com/matheusrb/panorama_covid19/master/Dados%20Combustível/ca-2023-01.csv'
            ]

for i, endereco in enumerate(enderecos):
  # Baixando o conteúdo do arquivo
  response = requests.get(enderecos[i])
  content = response.content

  # Detectando a codificação do conteúdo usando chardet
  result = chardet.detect(content)
  encoding = result['encoding']

  # Decodificando o conteúdo para UTF-8
  content_utf8 = content.decode(encoding)

  # Lendo o conteúdo decodificado com o Pandas
  df_combustivel_temp = pd.read_csv(StringIO(content_utf8), sep=";")
  df_combustivel = pd.concat([df_combustivel, df_combustivel_temp])

df_combustivel['Data da Coleta'] = pd.to_datetime(df_combustivel['Data da Coleta'], format='%d/%m/%Y')
df_combustivel.sort_values(by='Data da Coleta', inplace=True)
df_combustivel.head()
# Out:
# <ipython-input-3-62685e7f8b3c>:27: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_combustivel_temp = pd.read_csv(StringIO(content_utf8), sep=";")
#      Regiao - Sigla Estado - Sigla Municipio  \
# 0                 S             RS    CANOAS
# 5069              S             RS    CANOAS
# 5068              S             RS    CANOAS
# 5067              S             RS    CANOAS
# 5066              S             RS    CANOAS
#
#                                                 Revenda      CNPJ da Revenda  \
# 0           METROPOLITANO COMERCIO DE COMBUSTIVEIS LTDA   88.587.589/0001-17
# 5069  COMERCIAL BUFFON COMBUSTIVEIS E TRANSPORTES LI...   93.489.243/0026-74
# 5068  COMERCIAL BUFFON COMBUSTIVEIS E TRANSPORTES LI...   93.489.243/0026-74
# 5067  COMERCIAL BUFFON COMBUSTIVEIS E TRANSPORTES LI...   93.489.243/0026-74
# 5066  COMERCIAL BUFFON COMBUSTIVEIS E TRANSPORTES LI...   93.489.243/0026-74
#
# ...

# %%
#Elimina colunas irrelevantes para a análise
df_combustivel = df_combustivel[['Data da Coleta', 'Produto', 'Valor de Venda']]
df_combustivel.head()
# Out:
#      Data da Coleta     Produto Valor de Venda
# 0        2019-07-01    GASOLINA          4,259
# 5069     2019-07-01  DIESEL S10          3,569
# 5068     2019-07-01      DIESEL          3,469
# 5067     2019-07-01      ETANOL          4,129
# 5066     2019-07-01    GASOLINA          4,399

# %%
#corrige o data type do valor de venda
df_combustivel['Valor de Venda'] = df_combustivel['Valor de Venda'].str.replace(',', '.').astype(float)
df_combustivel.dtypes
# Out:
# Data da Coleta    datetime64[ns]
# Produto                   object
# Valor de Venda           float64
# dtype: object

# %%
#Organiza o data frame por ordem cronológica
df_combustivel.reset_index(drop=True, inplace=True)
df_combustivel.sort_values(by='Data da Coleta')
df_combustivel.head()
# Out:
#   Data da Coleta     Produto  Valor de Venda
# 0     2019-07-01    GASOLINA           4.259
# 1     2019-07-01  DIESEL S10           3.569
# 2     2019-07-01      DIESEL           3.469
# 3     2019-07-01      ETANOL           4.129
# 4     2019-07-01    GASOLINA           4.399

# %% [markdown]
# ## Criação do preço médio por data e tipo de produto

# %%
df_combustivel_medio = df_combustivel.groupby(['Data da Coleta', 'Produto'], as_index=False).agg({'Valor de Venda' : 'mean'})
df_combustivel_medio.reset_index(drop=True, inplace=True)
df_combustivel_medio.sort_values(by='Data da Coleta')
df_combustivel_medio.head(20)
# Out:
#    Data da Coleta     Produto  Valor de Venda
# 0      2019-07-01      DIESEL        3.556166
# 1      2019-07-01  DIESEL S10        3.644437
# 2      2019-07-01      ETANOL        3.163789
# 3      2019-07-01    GASOLINA        4.443734
# 4      2019-07-01         GNV        3.187778
# 5      2019-07-02      DIESEL        3.615884
# 6      2019-07-02  DIESEL S10        3.693764
# 7      2019-07-02      ETANOL        3.135132
# 8      2019-07-02    GASOLINA        4.457518
# 9      2019-07-02         GNV        3.311027
# 10     2019-07-03      DIESEL        3.535752
# 11     2019-07-03  DIESEL S10        3.639587
# 12     2019-07-03      ETANOL        3.043144
# 13     2019-07-03    GASOLINA        4.423816
# 14     2019-07-03         GNV        3.113103
# 15     2019-07-04      DIESEL        3.583447
# 16     2019-07-04  DIESEL S10        3.669704
# 17     2019-07-04      ETANOL        2.976667
# 18     2019-07-04    GASOLINA        4.387684
# ...

# %% [markdown]
# ### Criação das Médias Móveis dos Preços dos Combustíveis

# %% [markdown]
# #### Diesel

# %%
#Criação da media movel de 14 dias diesel
df_diesel_medio = df_combustivel_medio.loc[df_combustivel_medio['Produto'] == 'DIESEL']
df_diesel_medio.reset_index(drop=True, inplace=True)
df_diesel_medio['media_movel'] = df_diesel_medio['Valor de Venda'].rolling(14).mean()
df_diesel_medio.media_movel = df_diesel_medio.media_movel.fillna(df_diesel_medio.loc[13,'media_movel'])

df_diesel_medio.head(20)

# %% [markdown]
# #### Diesel S10

# %%
#Criação da media movel de 14 dias diesel-s10
df_diesel_s10_medio = df_combustivel_medio.loc[df_combustivel_medio['Produto'] == 'DIESEL S10']
df_diesel_s10_medio.reset_index(drop=True, inplace=True)
df_diesel_s10_medio['media_movel'] = df_diesel_s10_medio['Valor de Venda'].rolling(14).mean()
df_diesel_s10_medio.media_movel = df_diesel_s10_medio.media_movel.fillna(df_diesel_s10_medio.loc[13,'media_movel'])

df_diesel_s10_medio.head()

# %% [markdown]
# #### Gasolina

# %%
#Criação da media movel de 14 dias gasolina
df_gasolina_medio = df_combustivel_medio.loc[df_combustivel_medio['Produto'] == 'GASOLINA']
df_gasolina_medio.reset_index(drop=True, inplace=True)
df_gasolina_medio['media_movel'] = df_gasolina_medio['Valor de Venda'].rolling(14).mean()
df_gasolina_medio.media_movel = df_gasolina_medio.media_movel.fillna(df_gasolina_medio.loc[13,'media_movel'])

df_gasolina_medio.head()

# %% [markdown]
# #### Etanol

# %%
#Criação da media movel de 14 dias gasolina
df_etanol_medio = df_combustivel_medio.loc[df_combustivel_medio['Produto'] == 'ETANOL']
df_etanol_medio.reset_index(drop=True, inplace=True)
df_etanol_medio['media_movel'] = df_etanol_medio['Valor de Venda'].rolling(14).mean()
df_etanol_medio.media_movel = df_etanol_medio.media_movel.fillna(df_etanol_medio.loc[13,'media_movel'])

df_etanol_medio.head()

# %% [markdown]
# # Dados COVID

# %%
df = pd.read_csv('https://github.com/owid/covid-19-data/raw/master/public/data/owid-covid-data.csv')
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-01-03          NaN        0.0
# 1      AFG      Asia  Afghanistan  2020-01-04          NaN        0.0
# 2      AFG      Asia  Afghanistan  2020-01-05          NaN        0.0
# 3      AFG      Asia  Afghanistan  2020-01-06          NaN        0.0
# 4      AFG      Asia  Afghanistan  2020-01-07          NaN        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         0.0                  NaN  ...
# 1                 NaN           NaN         0.0                  NaN  ...
# 2                 NaN           NaN         0.0                  NaN  ...
# 3                 NaN           NaN         0.0                  NaN  ...
# 4                 NaN           NaN         0.0                  NaN  ...
#
#    male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# ...

# %%
df.date = pd.to_datetime(df.date, format='%Y-%m-%d')
df.dtypes
# Out:
# iso_code                                           object
# continent                                          object
# location                                           object
# date                                       datetime64[ns]
# total_cases                                       float64
#                                                 ...
# population                                        float64
# excess_mortality_cumulative_absolute              float64
# excess_mortality_cumulative                       float64
# excess_mortality                                  float64
# excess_mortality_cumulative_per_million           float64
# Length: 67, dtype: object

# %%
pd.set_option('display.max_rows', 100)
df.dtypes
# Out:
# iso_code                                              object
# continent                                             object
# location                                              object
# date                                          datetime64[ns]
# total_cases                                          float64
# new_cases                                            float64
# new_cases_smoothed                                   float64
# total_deaths                                         float64
# new_deaths                                           float64
# new_deaths_smoothed                                  float64
# total_cases_per_million                              float64
# new_cases_per_million                                float64
# new_cases_smoothed_per_million                       float64
# total_deaths_per_million                             float64
# new_deaths_per_million                               float64
# ...

# %% [markdown]
# ## Análise Exploratória dos Dados
#
# Neste momento o propósito é entender o que são os dados, ou seja, qual a situação em que eles se encontram. Isso significa entender a quantidade de dados que existe, se há muitos valores nulos ou incoerentes e como isso impacta nas conclusões em que se pode chegar, o que cada coluna/variável significa, dentre outras informações que podem extraídas com poucas linhas de código.
#
# ### Dicionário de variáveis
# ...
#
#
# ### Análise Exploratória Inicial
#
# * *Qual o tamanho do DataFrame?*
#
#        332565 linhas x 67 Colunas
#
# * *Quais os tipos das variáveis?*
#
#       iso_code                                              object
#       continent                                             object
#       location                                              object
#       date                                          datetime64[ns]
#       total_cases                                          float64
#       new_cases                                            float64
#       new_cases_smoothed                                   float64
#       total_deaths                                         float64
#       new_deaths                                           float64
#       new_deaths_smoothed                                  float64
#       total_cases_per_million                              float64
#       new_cases_per_million                                float64
#       new_cases_smoothed_per_million                       float64
#       total_deaths_per_million                             float64
#       new_deaths_per_million                               float64
#       new_deaths_smoothed_per_million                      float64
#       reproduction_rate                                    float64
#       icu_patients                                         float64
#       icu_patients_per_million                             float64
#       hosp_patients                                        float64
#       hosp_patients_per_million                            float64
#       weekly_icu_admissions                                float64
#       weekly_icu_admissions_per_million                    float64
#       weekly_hosp_admissions                               float64
#       weekly_hosp_admissions_per_million                   float64
#       total_tests                                          float64
#       new_tests                                            float64
#       total_tests_per_thousand                             float64
#       new_tests_per_thousand                               float64
#       new_tests_smoothed                                   float64
#       new_tests_smoothed_per_thousand                      float64
#       positive_rate                                        float64
#       tests_per_case                                       float64
#       tests_units                                           object
#       total_vaccinations                                   float64
#       people_vaccinated                                    float64
#       people_fully_vaccinated                              float64
#       total_boosters                                       float64
#       new_vaccinations                                     float64
#       new_vaccinations_smoothed                            float64
#       total_vaccinations_per_hundred                       float64
#       people_vaccinated_per_hundred                        float64
#       people_fully_vaccinated_per_hundred                  float64
#       total_boosters_per_hundred                           float64
#       new_vaccinations_smoothed_per_million                float64
#       new_people_vaccinated_smoothed                       float64
#       new_people_vaccinated_smoothed_per_hundred           float64
#       stringency_index                                     float64
#       population_density                                   float64
#       median_age                                           float64
#       aged_65_older                                        float64
#       aged_70_older                                        float64
#       gdp_per_capita                                       float64
#       extreme_poverty                                      float64
#       cardiovasc_death_rate                                float64
#       diabetes_prevalence                                  float64
#       female_smokers                                       float64
#       male_smokers                                         float64
#       handwashing_facilities                               float64
#       hospital_beds_per_thousand                           float64
#       life_expectancy                                      float64
#       human_development_index                              float64
#       population                                           float64
#       excess_mortality_cumulative_absolute                 float64
#       excess_mortality_cumulative                          float64
#       excess_mortality                                     float64
#       excess_mortality_cumulative_per_million              float64
#
#     *Nota: O tipo da coluna 'date' já foi alterado para DateTime*
#
# * *Porcentagem de valores ausentes*
#
#       weekly_icu_admissions                         0.970141
#       weekly_icu_admissions_per_million             0.970141
#       excess_mortality_cumulative_per_million       0.965315
#       excess_mortality                              0.965315
#       excess_mortality_cumulative                   0.965315
#       excess_mortality_cumulative_absolute          0.965315
#       weekly_hosp_admissions_per_million            0.931667
#       weekly_hosp_admissions                        0.931667
#       icu_patients_per_million                      0.896519
#       icu_patients                                  0.896519
#       hosp_patients                                 0.891627
#       hosp_patients_per_million                     0.891627
#       total_boosters_per_hundred                    0.861615
#       total_boosters                                0.861615
#       new_vaccinations                              0.807776
#       people_fully_vaccinated                       0.786800
#       people_fully_vaccinated_per_hundred           0.786800
#       people_vaccinated                             0.776459
#       people_vaccinated_per_hundred                 0.776459
#       new_tests                                     0.773268
#       new_tests_per_thousand                        0.773268
#       total_vaccinations                            0.766554
#       total_vaccinations_per_hundred                0.766554
#       total_tests                                   0.761289
#       total_tests_per_thousand                      0.761289
#       tests_per_case                                0.716302
#       positive_rate                                 0.711554
#       new_tests_smoothed_per_thousand               0.687384
#       new_tests_smoothed                            0.687384
#       tests_units                                   0.678896
#       handwashing_facilities                        0.620330
#       extreme_poverty                               0.501595
#       new_people_vaccinated_smoothed_per_hundred    0.472903
#       new_people_vaccinated_smoothed                0.472903
#       new_vaccinations_smoothed_per_million         0.472347
#       new_vaccinations_smoothed                     0.472347
#       reproduction_rate                             0.444268
#       male_smokers                                  0.426434
#       female_smokers                                0.418514
#       stringency_index                              0.405677
#       hospital_beds_per_thousand                    0.315707
#       human_development_index                       0.248607
#       aged_65_older                                 0.238293
#       gdp_per_capita                                0.226440
#       cardiovasc_death_rate                         0.224873
#       aged_70_older                                 0.218631
#       median_age                                    0.210723
#       diabetes_prevalence                           0.185326
#       total_deaths                                  0.176582
#       total_deaths_per_million                      0.176582
#       population_density                            0.151303
#       total_cases_per_million                       0.112931
#       total_cases                                   0.112931
#       life_expectancy                               0.080237
#       continent                                     0.047582
#       new_cases_smoothed                            0.031395
#       new_cases_smoothed_per_million                0.031395
#       new_deaths_smoothed_per_million               0.031128
#       new_deaths_smoothed                           0.031128
#       new_cases                                     0.027610
#       new_cases_per_million                         0.027610
#       new_deaths                                    0.027429
#       new_deaths_per_million                        0.027429
#       population                                    0.000000
#       date                                          0.000000
#       location                                      0.000000
#       iso_code                                      0.000000
#
# * *Colunas eliminadas do DF - Criério: valores ausentes > 0.25*
#
#       weekly_icu_admissions,
#       weekly_icu_admissions_per_million,
#       excess_mortality_cumulative_per_million,
#       excess_mortality,
#       excess_mortality_cumulative,
#       excess_mortality_cumulative_absolute,
#       weekly_hosp_admissions_per_million,
#       weekly_hosp_admissions,
#       icu_patients_per_million,
#       icu_patients,
#       hosp_patients,
#       hosp_patients_per_million,
#       total_boosters_per_hundred,
#       total_boosters,
#       new_vaccinations,
#       people_fully_vaccinated,
#       people_fully_vaccinated_per_hundred,
#       people_vaccinated,
#       people_vaccinated_per_hundred,
#       new_tests,
#       new_tests_per_thousand,
#       total_vaccinations,
#       total_vaccinations_per_hundred,
#       total_tests,
#       total_tests_per_thousand,
#       tests_per_case,
#       positive_rate,
#       new_tests_smoothed_per_thousand,
#       new_tests_smoothed,
#       tests_units,
#       handwashing_facilities,
#       extreme_poverty,
#       new_people_vaccinated_smoothed_per_hundred,
#       new_people_vaccinated_smoothed,
#       new_vaccinations_smoothed_per_million,
#       new_vaccinations_smoothed,
#       reproduction_rate,
#       male_smokers,
#       female_smokers,
#       stringency_index,
#       hospital_beds_per_thousand

# %%
#Tamanho do DF
df.shape
# Out:
# (334170, 67)

# %%
#nome das colunas
for column in df.columns:
  print(column)
# Out:
# iso_code
# continent
# location
# date
# total_cases
# new_cases
# new_cases_smoothed
# total_deaths
# new_deaths
# new_deaths_smoothed
# total_cases_per_million
# new_cases_per_million
# new_cases_smoothed_per_million
# total_deaths_per_million
# new_deaths_per_million
# new_deaths_smoothed_per_million
# reproduction_rate
# icu_patients
# icu_patients_per_million
# hosp_patients
# hosp_patients_per_million
# weekly_icu_admissions
# weekly_icu_admissions_per_million
# weekly_hosp_admissions
# weekly_hosp_admissions_per_million
# total_tests
# new_tests
# total_tests_per_thousand
# new_tests_per_thousand
# new_tests_smoothed
# new_tests_smoothed_per_thousand
# positive_rate
# tests_per_case
# tests_units
# total_vaccinations
# people_vaccinated
# people_fully_vaccinated
# total_boosters
# new_vaccinations
# new_vaccinations_smoothed
# total_vaccinations_per_hundred
# people_vaccinated_per_hundred
# people_fully_vaccinated_per_hundred
# total_boosters_per_hundred
# ...

# %%
percentual_nulo = (df.isnull().sum() / df.shape[0]).sort_values(ascending=False)
print(percentual_nulo)
# Out:
# weekly_icu_admissions                         0.970267
# weekly_icu_admissions_per_million             0.970267
# excess_mortality_cumulative_per_million       0.965482
# excess_mortality                              0.965482
# excess_mortality_cumulative                   0.965482
# excess_mortality_cumulative_absolute          0.965482
# weekly_hosp_admissions_per_million            0.931978
# weekly_hosp_admissions                        0.931978
# icu_patients_per_million                      0.896981
# icu_patients                                  0.896981
# hosp_patients                                 0.892127
# hosp_patients_per_million                     0.892127
# total_boosters_per_hundred                    0.862133
# total_boosters                                0.862133
# new_vaccinations                              0.808565
# people_fully_vaccinated                       0.787665
# people_fully_vaccinated_per_hundred           0.787665
# ...

# %% [markdown]
# As colunas que possuem mais de 25% de valores nulos sao eliminadas para facilitar a manipulação e o processamento dos dados, uma vez que devido a carencia de dados, trazem pouqíssima relevancia à análise.

# %%
#Colunas a serem eliminadas
columns = percentual_nulo[percentual_nulo > 0.25].index.tolist()
columns
# Out:
# ['weekly_icu_admissions',
#  'weekly_icu_admissions_per_million',
#  'excess_mortality_cumulative_per_million',
#  'excess_mortality',
#  'excess_mortality_cumulative',
#  'excess_mortality_cumulative_absolute',
#  'weekly_hosp_admissions_per_million',
#  'weekly_hosp_admissions',
#  'icu_patients_per_million',
#  'icu_patients',
#  'hosp_patients',
#  'hosp_patients_per_million',
#  'total_boosters_per_hundred',
#  'total_boosters',
#  'new_vaccinations',
#  'people_fully_vaccinated',
#  'people_fully_vaccinated_per_hundred',
#  'people_vaccinated',
#  'people_vaccinated_per_hundred',
#  'new_tests',
#  'new_tests_per_thousand',
#  'total_vaccinations',
#  'total_vaccinations_per_hundred',
#  'total_tests',
#  'total_tests_per_thousand',
#  'tests_per_case',
#  'positive_rate',
#  'new_tests_smoothed_per_thousand',
#  'new_tests_smoothed',
#  'tests_units',
#  'handwashing_facilities',
#  'extreme_poverty',
#  'new_people_vaccinated_smoothed_per_hundred',
# ...

# %%
df.drop(columns=columns, inplace=True)

# %%
for column in df.columns:
  print(column)
# Out:
# iso_code
# continent
# location
# date
# total_cases
# new_cases
# new_cases_smoothed
# total_deaths
# new_deaths
# new_deaths_smoothed
# total_cases_per_million
# new_cases_per_million
# new_cases_smoothed_per_million
# total_deaths_per_million
# new_deaths_per_million
# new_deaths_smoothed_per_million
# population_density
# median_age
# aged_65_older
# aged_70_older
# gdp_per_capita
# cardiovasc_death_rate
# diabetes_prevalence
# life_expectancy
# human_development_index
# population

# %%
df_sa = df.loc[df.continent == 'South America'].sort_values(by='date', ascending=False)

# %%
df_paises_sa = df_sa.groupby(['location'], as_index=False).agg({'total_cases' : 'max',
                                                                'total_deaths' : 'max',
                                                                'gdp_per_capita' : 'first',
                                                                'human_development_index' : 'first',
                                                                'population' : 'first'}).sort_values(by='total_deaths')
df_paises_sa['per_rel_cases'] = df_paises_sa.total_cases/df_paises_sa.population*100
df_paises_sa['per_rel_deaths'] = df_paises_sa.total_deaths/df_paises_sa.population*100
df_paises_sa.dropna(inplace=True)

# %% [markdown]
# ## Análise de óbitos por países na América do Sul

# %% [markdown]
# ### Número absoluto de óbitos por país

# %%
fig, ax = plt.subplots(figsize=(12, 6))

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#Gráfico 1 - estados + brasil
ax.barh(df_paises_sa.location, df_paises_sa.total_deaths)
ax.grid(axis='x', color='gray', alpha=0.25, linewidth=0.75, )
ax.set_xlabel("País")
ax.set_title('Total de óbitos por país da América do Sul')


plt.tight_layout()

# %% [markdown]
# ### Percentual do número de óbitos/habitatnes

# %%
df_paises_sa.sort_values(by='per_rel_deaths', inplace=True)
fig, ax = plt.subplots(figsize=(12, 6))

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#Gráfico 1 - estados + brasil
ax.barh(df_paises_sa.location, df_paises_sa.per_rel_deaths)
ax.grid(axis='x', color='gray', alpha=0.25, linewidth=0.75, )
ax.set_ylabel("% de óbitos")
ax.set_ylabel("País")
ax.set_title('% de óbitos/hab dos países da América do Sul')


plt.tight_layout()

# %%
df_sa = df.loc[df.continent == 'South America'].sort_values(by='date', ascending=False)

# %%
df_paises_sa = df_sa.groupby(['location'], as_index=False).agg({'total_cases' : 'max',
                                                                'total_deaths' : 'max',
                                                                'gdp_per_capita' : 'first',
                                                                'human_development_index' : 'first',
                                                                'population' : 'first'}).sort_values(by='total_deaths')
df_paises_sa['per_rel_cases'] = df_paises_sa.total_cases/df_paises_sa.population*100
df_paises_sa['per_rel_deaths'] = df_paises_sa.total_deaths/df_paises_sa.population*100
df_paises_sa.dropna(inplace=True)

# %% [markdown]
# ## Análise de casos por países na América do Sul

# %% [markdown]
# ### Número absoluto de casos por país da américa do sul

# %%
df_paises_sa.sort_values(by='total_cases', inplace=True)

fig, ax = plt.subplots(figsize=(12, 6))

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#Gráfico 1 - estados + brasil
ax.barh(df_paises_sa.location, df_paises_sa.total_cases)
ax.grid(axis='x', color='gray', alpha=0.25, linewidth=0.75, )
ax.set_xlabel("País")
ax.set_title('Total de casos por país da América do Sul')


plt.tight_layout()

# %% [markdown]
# ### Percentual do número de casos/habitatnes

# %%
df_paises_sa.sort_values(by='per_rel_cases', inplace=True)
fig, ax = plt.subplots(figsize=(12, 6))

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

#Gráfico 1 - estados + brasil
ax.barh(df_paises_sa.location, df_paises_sa.per_rel_cases)
ax.grid(axis='x', color='gray', alpha=0.25, linewidth=0.75, )
ax.set_ylabel("% de óbitos")
ax.set_ylabel("País")
ax.set_title('% de óbitos/hab dos países da América do Sul')


plt.tight_layout()

# %% [markdown]
# ## Extrai base dados referente ao Brasil
#
# Para facilitar o trabalho, será criado um novo *dataframe* contendo informações do Brasil (por se tratar de uma base de dados internacional, o filtro é usado como 'Brazil'). O novo *df* está organizando em órdem decrescente de data

# %%
df_brasil = df.loc[df.location == 'Brazil'].sort_values(by='date')
df_brasil.reset_index(inplace=True, drop=True)
df_brasil.head(15)
# Out:
#    iso_code      continent location       date  total_cases  new_cases  \
# 0       BRA  South America   Brazil 2020-01-03          NaN        0.0
# 1       BRA  South America   Brazil 2020-01-04          NaN        0.0
# 2       BRA  South America   Brazil 2020-01-05          NaN        0.0
# 3       BRA  South America   Brazil 2020-01-06          NaN        0.0
# 4       BRA  South America   Brazil 2020-01-07          NaN        0.0
# 5       BRA  South America   Brazil 2020-01-08          NaN        0.0
# 6       BRA  South America   Brazil 2020-01-09          NaN        0.0
# 7       BRA  South America   Brazil 2020-01-10          NaN        0.0
# 8       BRA  South America   Brazil 2020-01-11          NaN        0.0
# 9       BRA  South America   Brazil 2020-01-12          NaN        0.0
# 10      BRA  South America   Brazil 2020-01-13          NaN        0.0
# 11      BRA  South America   Brazil 2020-01-14          NaN        0.0
# ...

# %%
#Organiza os valores do df por ordem cronológica para os próximos plots
df_brasil.sort_values(by='date', inplace=True)
fig, ax = plt.subplots(figsize=(15, 6))

#plot numero acumulado de obitos
ax.plot(df_brasil['date'], df_brasil['total_deaths'], label='Acumulado de óbitos')
ax.grid(visible=True)
ax.set_xlabel('Data')

plt.tight_layout()

# %% [markdown]
# ## Evolução dos casos no Brasil
# Abaixo segue um gráfico da evolução diária de novos casos, foi usada também uma média móvel que filtra os valores e torna possível a visualização de uma tendência mais clara, especialmente quando são utilizadas janelas de tempo menores.
#
# Inicialmente foi necessário tratar valores de novos casos para que valores nulos fossem preenchidos pelo seu antecessor, algo possível devido ao bom volume de dados de qualidade existentes.

# %% [markdown]
# ### Criação médias móveis - Brasil
# Criação de médias moveis de novos casos e novos óbitos no Brasil

# %%
#Tratamento para criação da media movel
df_brasil.new_cases = df_brasil.new_cases.fillna(0)
df_brasil.new_deaths = df_brasil.new_deaths.fillna(0)

#definição do período da média móvel
dias_media_movel = 14

#Criação da media movel de 14 dias
df_brasil['media_movel_casos'] = df_brasil.new_cases.rolling(dias_media_movel).mean()
df_brasil.media_movel_casos = df_brasil.media_movel_casos.fillna(0)

#Criação da media movel de 14 dias
df_brasil['media_movel_obitos'] = df_brasil.new_deaths.rolling(dias_media_movel).mean()
df_brasil.media_movel_obitos = df_brasil.media_movel_obitos.fillna(0)
df_brasil.head(100)
# Out:
#    iso_code      continent location       date  total_cases  new_cases  \
# 0       BRA  South America   Brazil 2020-01-03          NaN        0.0
# 1       BRA  South America   Brazil 2020-01-04          NaN        0.0
# 2       BRA  South America   Brazil 2020-01-05          NaN        0.0
# 3       BRA  South America   Brazil 2020-01-06          NaN        0.0
# 4       BRA  South America   Brazil 2020-01-07          NaN        0.0
# 5       BRA  South America   Brazil 2020-01-08          NaN        0.0
# 6       BRA  South America   Brazil 2020-01-09          NaN        0.0
# 7       BRA  South America   Brazil 2020-01-10          NaN        0.0
# 8       BRA  South America   Brazil 2020-01-11          NaN        0.0
# 9       BRA  South America   Brazil 2020-01-12          NaN        0.0
# 10      BRA  South America   Brazil 2020-01-13          NaN        0.0
# 11      BRA  South America   Brazil 2020-01-14          NaN        0.0
# ...

# %% [markdown]
# ### Criação médias móveis - Mundo
# Criação de médias moveis de novos casos e novos óbitos no Mundo

# %%
#Cria uma média movel do mundo todo para fins de comparação em termos de tendencia
df_world = df.groupby(['date'], as_index=False).agg({'new_cases' : 'sum', 'new_deaths' : 'sum'})
#Tratamento para criação da media movel
df_world.new_cases = df_world.new_cases.fillna(0)
df_world.new_deaths = df_world.new_deaths.fillna(0)

#definição do período da média móvel
dias_media_movel = 14

#Criação da media movel de 14 dias
df_world['media_movel_casos'] = df_world.new_cases.rolling(dias_media_movel).mean()
df_world.media_movel_casos = df_world.media_movel_casos.fillna(0)

#Criação da media movel de 14 dias
df_world['media_movel_obitos'] = df_world.new_deaths.rolling(dias_media_movel).mean()
df_world.media_movel_obitos = df_world.media_movel_obitos.fillna(0)
df_world.head(20)
# Out:
#          date  new_cases  new_deaths  media_movel_casos  media_movel_obitos
# 0  2020-01-01        0.0         0.0           0.000000            0.000000
# 1  2020-01-02        0.0         0.0           0.000000            0.000000
# 2  2020-01-03        0.0         0.0           0.000000            0.000000
# 3  2020-01-04       14.0         0.0           0.000000            0.000000
# 4  2020-01-05        0.0        15.0           0.000000            0.000000
# 5  2020-01-06       12.0         0.0           0.000000            0.000000
# 6  2020-01-07        0.0         0.0           0.000000            0.000000
# 7  2020-01-08        4.0         0.0           0.000000            0.000000
# 8  2020-01-09        0.0         0.0           0.000000            0.000000
# 9  2020-01-10        0.0         0.0           0.000000            0.000000
# 10 2020-01-11        0.0         0.0           0.000000            0.000000
# ...

# %% [markdown]
# ## Visualização da progressão de casos e óbitos
# Abaixo tem-se uma visualização da progressão de novos casos e novos óbitos no mundo todo, bem como suas médias móveis.
# As médias móveis nçao foram normalizadas uma vez que a intenção é apenas de se comparar a agressividade na variação da curva de maneira visual, além disso, os números referentes ao Brasil nao foram excluídos das curvas do Mundo.

# %% [markdown]
# ### Casos

# %%
df_brasil.sort_values(by='date', inplace=True)
fig, ax1 = plt.subplots(figsize=(15, 8))


#plot novos obitos diário
ax1.plot(df_brasil['date'], df_brasil['new_cases'], label='Novos casos Brasil')
#plot MM de obitos
ax1.plot(df_brasil['date'], df_brasil['media_movel_casos'], label='Média móvel de 2 semanas de novos casos Brasil', color='r')
ax1.grid(axis='x', color='gray', alpha=0.25, linewidth=0.75, )
ax1.set_xlabel('Data')
ax1.set_ylabel('Novos Casos no Brasil')
ax1.set_title('Novos Casos')

#Criação da curva do mundo
ax2 = ax1.twinx()

#plot novos obitos diário
#ax2.plot(df_world['date'], df_world['new_cases'], label='Novos óbitos mundo', color='g')
#plot MM de obitos
ax2.plot(df_world['date'], df_world['media_movel_casos'], label='Média móvel de 2 semanas de novos casos mundo', color='purple')
ax2.grid(axis='x', color='gray', alpha=0.25, linewidth=0.75)
ax2.set_xlabel('Data')
ax2.set_ylabel('Novos Casos no Mundo')

# Definindo a janela de tempo a ser destacada
start_time = '2021-01-19'
end_time = '2021-01-20'

# Adicionando um retângulo para destacar a janela de tempo
ax2.axvspan(start_time, end_time, color='green', alpha=1, label='Início da vacinação no Brasil')


ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)

ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)


# Definindo a janela de tempo a ser destacada
start_time = '2021-12-03'
end_time = '2021-12-04'

# Adicionando um retângulo para destacar a janela de tempo
ax2.axvspan(start_time, end_time, color='red', alpha=1, label='Primeiro caso Omicron no Brasil')

#seta legenda
curvas, labels = ax1.get_legend_handles_labels()
curva2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(curvas + curva2, labels + labels2, loc='upper left')

plt.savefig('Curva novos casos.png')
plt.savefig('Curva novos casos.svg')

plt.tight_layout()

# %% [markdown]
# ### Óbitos

# %%
fig, ax1 = plt.subplots(figsize=(15, 8))

#plot novos obitos diário
ax1.plot(df_brasil['date'], df_brasil['new_deaths'], label='Novos óbitos Brasil')
#plot MM de obitos
ax1.plot(df_brasil['date'], df_brasil['media_movel_obitos'], label='Média móvel de 2 semanas de novos óbitos Brasil', color='r')
ax1.grid(axis='x', color='gray', alpha=0.25, linewidth=0.75, )
ax1.set_xlabel('Data')
ax1.set_ylabel('Novos Óbitos no Brasil')
ax1.set_title('Novos Óbitos')

#Criação da curva do mundo
ax2 = ax1.twinx()

#plot novos obitos diário
#ax2.plot(df_world['date'], df_world['new_cases'], label='Novos óbitos mundo', color='g')
#plot MM de obitos
ax2.plot(df_world['date'], df_world['media_movel_obitos'], label='Média móvel de 2 semanas de novos óbitos mundo', color='purple')
ax2.grid(axis='x', color='gray', alpha=0.25, linewidth=0.75)
ax2.set_xlabel('Data')
ax2.set_ylabel('Novos Óbitos no Mundo')

# Definindo a janela de tempo a ser destacada
start_time = '2021-01-19'
end_time = '2021-01-20'

# Adicionando um retângulo para destacar a janela de tempo
ax2.axvspan(start_time, end_time, color='green', alpha=1, label='Início da vacinação no Brasil')


ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)

ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)

# Definindo a janela de tempo a ser destacada
start_time = '2021-12-03'
end_time = '2021-12-04'

# Adicionando um retângulo para destacar a janela de tempo
ax2.axvspan(start_time, end_time, color='red', alpha=1, label='Primeiro caso Omicron no Brasil')

#seta legenda
curvas, labels = ax1.get_legend_handles_labels()
curva2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(curvas + curva2, labels + labels2, loc='upper right')

plt.savefig('Curva novos obitos.png')
plt.savefig('Curva novos obitos.svg')

plt.tight_layout()
plt.show()

# %%
linhas = 2
colunas = 2

df_brasil.sort_values(by='date', inplace=True)
fig, ax1 = plt.subplots(nrows=linhas, ncols=colunas,figsize=(25, 25))

for i in range(linhas):
  for j in range(colunas):
    #plot MM de casos
    ax1[i,j].plot(df_brasil['date'], df_brasil['media_movel_casos'], label='Média móvel de 14 dias de novos casos Brasil', color='r')
    ax1[i,j].set_xlabel('Data')
    ax1[i,j].set_ylabel('Novos Casos')
    #ax1[i,j].set_title('Tendencia de óbitos no Brasil + ')

# Criação dos eixos ax2 para cada subplot
ax2 = [[ax.twinx() for ax in row] for row in ax1]

#plot média preço de venda diesel
ax2[0][0].plot(df_diesel_medio['Data da Coleta'], df_diesel_medio['Valor de Venda'], label='Valor de Venda Médio do Diesel', color='g')
#plot média movel do preço medio de venda do diesel
ax2[0][0].plot(df_diesel_medio['Data da Coleta'], df_diesel_medio['media_movel'], label='Média Móvel do Valor de Venda Médio do Diesel', color='orange')
ax2[0][0].set_ylabel('Preço Diesel')
ax2[0][0].set_title('Relação Novos Casos e Preço Diesel')

#plot média preço de venda diesel S10
ax2[0][1].plot(df_diesel_s10_medio['Data da Coleta'], df_diesel_s10_medio['Valor de Venda'], label='Valor de Venda Médio do Diesel S10', color='g')
#plot média movel do preço medio de venda do diesel S10
ax2[0][1].plot(df_diesel_s10_medio['Data da Coleta'], df_diesel_s10_medio['media_movel'], label='Média Móvel do Valor de Venda Médio do Diesel S10', color='orange')
ax2[0][1].set_ylabel('Preço Diesel S10')
ax2[0][1].set_title('Relação Novos Casos e Preço Diesel S10')

#plot média preço de venda gasolina
ax2[1][0].plot(df_gasolina_medio['Data da Coleta'], df_gasolina_medio['Valor de Venda'], label='Valor de Venda Médio da Gasolina', color='g')
#plot média movel do preço medio de venda da Gasolina
ax2[1][0].plot(df_gasolina_medio['Data da Coleta'], df_gasolina_medio['media_movel'], label='Média Móvel do Valor de Venda Médio da Gasolina', color='orange')
ax2[1][0].set_ylabel('Preço Gasolina')
ax2[1][0].set_title('Relação Novos Casos e Preço Gasolina')

#plot média preço de venda etanol
ax2[1][1].plot(df_etanol_medio['Data da Coleta'], df_etanol_medio['Valor de Venda'], label='Valor de Venda Médio do Etanol', color='g')
#plot média movel do preço medio de venda do Etanol
ax2[1][1].plot(df_etanol_medio['Data da Coleta'], df_etanol_medio['media_movel'], label='Média Móvel do Valor de Venda Médio do Etanol', color='orange')
ax2[1][1].set_ylabel('Preço Etanol')
ax2[1][1].set_title('Relação Novos Casos e Preço Etanol')


for i in range(linhas):
  for j in range(colunas):
    #seta legenda
    curvas, labels = ax1[i,j].get_legend_handles_labels()
    curva2, labels2 = ax2[i][j].get_legend_handles_labels()
    ax2[i][j].legend(curvas + curva2, labels + labels2, loc='upper left')

    ax1[i,j].spines['top'].set_visible(False)
    ax1[i,j].spines['right'].set_visible(False)
    ax1[i,j].spines['left'].set_visible(False)
    ax1[i,j].grid(axis='x', color='gray', alpha=0.25, linewidth=0.75, )
    #ax1[i,j].grid(axis='y', color='gray', alpha=0.25, linewidth=0.75, linestyle='dashed')

    ax2[i][j].spines['top'].set_visible(False)
    ax2[i][j].spines['right'].set_visible(False)
    ax2[i][j].spines['left'].set_visible(False)
    ax2[i][j].grid(axis='x', color='gray', alpha=0.25, linewidth=0.75, )
    ax2[i][j].grid(axis='y', color='gray', alpha=0.25, linewidth=0.75, linestyle='dashed')

plt.savefig('Evolucao de caosos e combustível.png')
plt.savefig('Evolucao de caosos e combustível.svg')

plt.tight_layout()

# %% [markdown]
# ## Dados IGPM

# %%
df_igpm = pd.read_csv('https://raw.githubusercontent.com/matheusrb/panorama_covid19/master/IGPM.csv', sep=',')
df_igpm.fillna(0)
df_igpm.head()
# Out:
#    Unnamed: 0   Jan   Fev   Mar   Abr   Mai   Jun   Jul   Ago   Set   Out  \
# 0        2023  0.21 -0.06  0.05 -0.95 -1.84 -1.93 -0.72   NaN   NaN   NaN
# 1        2022  1.82  1.83  1.74  1.41  0.52  0.59  0.21 -0.70 -0.95 -0.97
# 2        2021  2.58  2.53  2.94  1.51  4.10  0.60  0.78  0.66 -0.64  0.64
# 3        2020  0.48 -0.04  1.24  0.80  0.28  1.56  2.23  2.74  4.34  3.23
# 4        2019  0.01  0.88  1.26  0.92  0.45  0.80  0.40 -0.67 -0.01  0.68
#
#     Nov   Dez
# 0   NaN   NaN
# 1 -0.56  0.45
# 2  0.02  0.87
# 3  3.28  0.96
# 4  0.30  2.09

# %%
import calendar
# Usar a função melt para transformar a tabela
df_transformado = pd.melt(df_igpm, id_vars=['Unnamed: 0'], value_vars=['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'],
                           var_name='mes', value_name='valor')

# Juntar o mês e o ano em uma única coluna
df_transformado['mes_ano'] = df_transformado['mes'] + ' ' + df_transformado['Unnamed: 0'].astype(str)

# Excluir as colunas 'mes' e 'Unnamed: 0'
df_transformado = df_transformado.drop(['mes', 'Unnamed: 0'], axis=1)

# Dicionário de tradução de nomes de meses em português para inglês
meses_dict = {
    'Jan': 'January',
    'Fev': 'February',
    'Mar': 'March',
    'Abr': 'April',
    'Mai': 'May',
    'Jun': 'June',
    'Jul': 'July',
    'Ago': 'August',
    'Set': 'September',
    'Out': 'October',
    'Nov': 'November',
    'Dez': 'December'
}

# Aplicar a tradução dos nomes de meses
df_transformado['mes_ano'] = df_transformado['mes_ano'].apply(lambda x: ' '.join([meses_dict[mes] if mes in meses_dict else mes for mes in x.split()]))

# Transformar a coluna 'mes_ano' em um objeto datetime com o último dia de cada mês
df_transformado['mes_ano'] = pd.to_datetime(df_transformado['mes_ano'], format='%B %Y') + pd.offsets.MonthEnd()

df_transformado = df_transformado.sort_values(by='mes_ano')

# Criar uma nova coluna 'acumulado' com os valores acumulados da coluna 'valor'
df_transformado['acumulado_igpm'] = df_transformado['valor'].cumsum()

df_transformado.head()
# Out:
#     valor    mes_ano  acumulado_igpm
# 4    0.01 2019-01-31            0.01
# 9    0.88 2019-02-28            0.89
# 14   1.26 2019-03-31            2.15
# 19   0.92 2019-04-30            3.07
# 24   0.45 2019-05-31            3.52

# %%
fig, ax1 = plt.subplots(figsize=(15, 8))

#plot MM de casos
ax1.plot(df_brasil['date'], df_brasil['media_movel_casos'], label='Média móvel de 14 dias de novos casos Brasil', color='r')
ax1.set_xlabel('Data')
ax1.set_ylabel('Novos Casos')
#ax1.set_title('Tendencia de óbitos no Brasil + ')

# Criação dos eixos ax2 para cada subplot
ax2 = ax1.twinx()

#plot média preço de venda diesel
ax2.plot(df_transformado['mes_ano'], df_transformado['acumulado_igpm'], label='IGPM Acumulado', color='g')
#ax2.plot(df_transformado['mes_ano'], df_transformado['acumulado_igpm'], label='IGPM Acumulado', color='b')
ax2.set_ylabel('IGPM')
ax2.set_title('Relação Novos Casos e IGPM acumulado')


# Definindo a janela de tempo a ser destacada
start_time = '2020-02-26'
end_time = '2021-06-25'

# Adicionando um retângulo para destacar a janela de tempo
ax2.axvspan(start_time, end_time, color='gray', alpha=0.3, label='Primeira fase da CONVID no Brasil')



#seta legenda
curvas, labels = ax1.get_legend_handles_labels()
curva2, labels2 = ax2.get_legend_handles_labels()
ax2.legend(curvas + curva2, labels + labels2, loc='upper left')

#Remove linhas de contorno
ax1.spines['top'].set_visible(False)
ax1.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax1.grid(axis='x', color='gray', alpha=0.25, linewidth=0.75, )

ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax2.grid(axis='x', color='gray', alpha=0.25, linewidth=0.75, )



plt.tight_layout()

# %% [markdown]
# ## Conclusão
#
# É indiscutível o quanto a pandemia impactou a maneira como se vive no mundo, bem como suas sequelas ainda serão vistas por mais algum tempo, especialmente em termos sociais, uma vez que houve alta na taxa de desempregados, defasagem no ensino e impactos econômicos como inflação e, por consequencia, uma alta das taxas de juros e redução do poder de comsumo.
# Utilizando os dados é possível inferir que, apesar do atraso em relação ao mundo no que se diz respeito a reação, o Brasil ainda teve menos óbitos relativos que seus vizinhos.
# Também é interessante notar que há uma relação entre o aumento do preço dos combustíveis e o aumento do número de casos. Com a insegurança socio-política causada pela COVID é natural o movimento de saída de investimentos de países com moedas mais fracas e sua realocação em moeda mais forte, gerando aumento na cotação do Dólar, bem como desvalorização do Real. Tal aumento acarretou no aumento dos preços de combustíveis, uma vez que na época, a Petrobrás - maior beneficiadora de petroleo do país - ainda tinha vigente sua politica de paridade de preço internacional.
#
# Em termos sanitários observa-se que, mesmo com as vacinações tendo começado no começo de 2021,  ainda assim não foi suficiente para conter a nova variante Omicron, que elevou o número de mortos de maneira substancialmente agressiva logo no início de 2022. De maneira expeculativa é possível questionar se esta alta de casos causada pela Omicron também está associada a um relaxamento no que se diz respeito aos cuidados exigidos ao longo da pandemia, bem como às festas de fim de ano como potencializadores do número de casos e, por consequencia, óbitos no mundo todo registrado nesta época.
#
# Por fim, é nítido que a crise sanitária vem sendo controlada no Brasil, tal evidencia se dá quando comparadas as variações entre as médias móveis do Brasil e do mundo no pico mais recente de COVID, em que é possível notar uma variação muito mais suave em terras tupiniquins que no mundo como um todo.
#
# Apesar de o controle da crise e das sequelas citadas no inicio do texto, ficaram alguns hábitos benéficos. De maneira geral, a pandemia deixou uma lição de higiêne e cuidado pessoal, bem como trouxe novas culturas como a de se utilizar máscara para se proteger e proteger o outro, algo que perdura até então.
